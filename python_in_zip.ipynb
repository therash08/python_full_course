# %%
name = ['Alice', 'Bob', 'Charlie']
university = ['Harvard', 'MIT', 'Stanford']

# %%
zipped = list(zip(name, university))
print(zipped)
# Out:
# [('Alice', 'Harvard'), ('Bob', 'MIT'), ('Charlie', 'Stanford')]

# %%
zipped = dict(zip(name, university))
print(zipped)
# Out:
# {'Alice': 'Harvard', 'Bob': 'MIT', 'Charlie': 'Stanford'}

# %%
zipped.keys()
# Out:
# dict_keys(['Alice', 'Bob', 'Charlie'])

# %%
zipped.values()
# Out:
# dict_values(['Harvard', 'MIT', 'Stanford'])

# %% [markdown]
# unzip

# %%
zipped = list(zip(name, university))
zipped
# Out:
# [('Alice', 'Harvard'), ('Bob', 'MIT'), ('Charlie', 'Stanford')]

# %%
name1, university1 = zip(*zipped)
name1
# Out:
# ('Alice', 'Bob', 'Charlie')

# %%
university1
# Out:
# ('Harvard', 'MIT', 'Stanford')

# %%
type(zipped)
# Out:
# list

# %%
text = 'i am learning python and python is fun'

# %%
import re

# %%
re.sub('python', 'java', text)
# Out:
# 'i am learning java and java is fun'
