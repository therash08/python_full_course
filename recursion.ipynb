# %%
def show(n):
    if (n == 0):
        return 
    print(n)
    show (n-1)

# %%
def show(n):
    if (n == 0):
        return
    print(n)
    show(n-1)
    
show(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
name = "rasidul_hoque"
name.find("hoque")
# Out:
# 8

# %%
name.find("b")
# Out:
# -1

# %%
name.index('ai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name.index('ai')
#
# ValueError: substring not found

# %%
name.lower()
# Out:
# 'rasidul_hoque'

# %%
name.upper()
# Out:
# 'RASIDUL_HOQUE'

# %%
name.casefold()
# Out:
# 'rasidul_hoque'

# %%
x = 'rasidul hoque chowdhury is me'
x.capitalize()
# Out:
# 'Rasidul hoque chowdhury is me'

# %%
x.swapcase()
# Out:
# 'RASIDUL HOQUE CHOWDHURY IS ME'

# %%
name.capitalize()
# Out:
# 'Rasidul_hoque'

# %%
x.title()
# Out:
# 'Rasidul Hoque Chowdhury Is Me'

# %%
x.islower()
# Out:
# True

# %%
x.isupper()
# Out:
# False

# %%
x.encode()
# Out:
# b'rasidul hoque chowdhury is me'

# %%
type(x.encode())
# Out:
# bytes

# %%
x.split()
# Out:
# ['rasidul', 'hoque', 'chowdhury', 'is', 'me']

# %%
x.split()[2]
# Out:
# 'chowdhury'

# %%
x.center(50)
# Out:
# '          rasidul hoque chowdhury is me           '

# %%
x = 10
y = 100
z = x*y
z
# Out:
# 1000

# %%
print('i have {} taka'.format(z))
# Out:
# i have 1000 taka
