# %%
first_name = 'rash'

print(first_name)
# Out:
# rash

# %%
first_name = 'rash'

print(f"hello {first_name}")
# Out:
# hello rash

# %%
food = 'pizza'
print(f"you like {food}")
# Out:
# you like pizza

# %%
email = 'therash792@gmail.com'

print(f"your email is: {email}")
# Out:
# your email is: therash792@gmail.com

# %%
age = 23
print(age)
# Out:
# 23

# %%
name_of_students = 40
print(f"your class has {name_of_students} students")
# Out:
# your class has 40 students

# %%
price = 10.45
print(f"the price is ${price}")
# Out:
# the price is $10.45

# %%
gpa = 4.67
print(f"the gpa is: {gpa}")
# Out:
# the gpa is: 4.67

# %%
is_student = True
print(f" are you student?: {is_student}")
# Out:
#  are you student?: True

# %%
is_student = False

if is_student:
    print("you are a student")
else:
    print("you are not  a student")
# Out:
# you are not  a student
