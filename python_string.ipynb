# %%
s = "GeeksforGeeks"
print(s[0])   # first character
print(s[4])   # 5th character
# Out:
# G
# s

# %%
s = "GeeksforGeeks"
print(s[-10])   # 3rd character
print(s[-5])    # 5th character from end
# Out:
# k
# G

# %%
s = "Python"
for char in s:
    print(char)
# Out:
# P
# y
# t
# h
# o
# n

# %%
s = "geeksforGeeks"
s = "G" + s[1:]   # create new string
print(s)
# Out:
# GeeksforGeeks

# %%
s = "Hello "
print(s * 3)
# Out:
# Hello Hello Hello

# %%
s = "GeeksforGeeks"
print("Geeks" in s)
print("GfG" in s)
# Out:
# True
# False

# %%
s = "Hello, Python!"

print(s[0:5])
# Out:
# Hello

# %%
s = "abcdefghijklmno"

print(s[-4:])

print(s[:-3])

print(s[-5:-2])

print(s[-8:-1:2])
# Out:
# lmno
# abcdefghijkl
# klm
# hjln

# %%
s = "Rasidul"

# Reverse the string
print(s[::-1])
# Out:
# ludisaR

# %%
s = "Hello, World!"

# Get the entire string
s2 = s[:]
s3 = s[::]

print(s2)
print(s3)
# Out:
# Hello, World!
# Hello, World!

# %%
s = "Hello, World!"

# Characters from index 1 to index 5 (excluding 5)
print(s[1:5])
# Out:
# ello

# %%
name = input("enter your full name:  ")
# len(name)

result = name.find("l")
result
# Out:
# 6

# %%
name = input("enter your full name:  ")

result = name.rfind("r")
result
# Out:
# 0

# %%
name = input("enter your full name:  ")

name = name.capitalize()
name
# Out:
# 'Rasidul hoque'

# %%
name = input("enter your full name:  ")
name = name.upper()
name
# Out:
# 'RASIDUL HOQUE'

# %%
name = input("enter your full name:  ")

name = name.lower()
name
# Out:
# 'rasidul hoque'

# %%
name = input("enter your full name:  ")

result = name.isdigit()
result
# Out:
# False

# %%
name = input("enter your full name:  ")
name = name.isalpha()
name
# Out:
# True

# %%
phn_number = input("enter your number: ")
result = phn_number.count("-")
result
# Out:
# 4

# %%
result = phn_number.replace("-", " ")
result
# Out:
# '1 22 333345 433 221'

# %%
print(help(str))
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
username = input("enter a username")

if len(username) > 12:
    print("your username can't be more than 12 characters")

elif not username.find(" ") == -1:
    print("your username cant contain spaces")
    
elif not username.isalpha():
    print("your username cant contain numbers")

else:
    print(f"welcome {username}")
# Out:
# welcome rasidulooo

# %% [markdown]
# string index

# %%
credit_number = "1234-5678-9076-6789"

print(credit_number[0])
# Out:
# 1

# %%
print(credit_number[0:4])
# Out:
# 1234

# %%
print(credit_number[5:9])
# Out:
# 5678

# %%
print(credit_number[::])
# Out:
# 1234-5678-9076-6789

# %%
print(credit_number[1:3:2])
# Out:
# 2

# %%
last_digit = credit_number[-4:]
