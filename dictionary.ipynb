# %%
info = {
    "key" : "value",
    "name" : "Rasidul",
    "learning" : "code"
}

print(info)
# Out:
# {'key': 'value', 'name': 'Rasidul', 'learning': 'code'}

# %%
info = {
    "name" : "rasidul",
    "subject" : ["c", "python", "java"],
    "topics" : ("dict", "set"),
    "age" : 65,
    "is_adult " : True,
    "marks" : 89.9
}

print(type(info))
# Out:
# <class 'dict'>

# %%
info = {
    "name" : "rasidul",
    "subject" : ["c", "python", "java"],
    "topics" : ("dict", "set"),
    "age" : 65,
    "is_adult " : True,
    "marks" : 89.9
}

print(info["name"])
print(info["topics"])
print(info["subject"])
# Out:
# rasidul
# ('dict', 'set')
# ['c', 'python', 'java']

# %%
info = {
    "name" : "rasidul",
    "subject" : ["c", "python", "java"],
    "topics" : ("dict", "set"),
    "age" : 65,
    "is_adult " : True,
    "marks" : 89.9
}
# info["name"] = "chowdhury"
# print(info)

null_dict = {}
print(null_dict)
# Out:
# {}

# %%
student = {
    "name" : "rasidul hoque",
    "subject" : {
        "phy" : 98,
        "chem" : 89,
        "math" : 86
    }
}

print(student["subject"])
# Out:
# {'phy': 98, 'chem': 89, 'math': 86}

# %%
student = {
    "name" : "rasidul hoque",
    "subject" : {
        "phy" : 98,
        "chem" : 89,
        "math" : 86
    }
}

# print(student.keys())

print(list(student.values()))
# Out:
# ['rasidul hoque', {'phy': 98, 'chem': 89, 'math': 86}]

# %%
student = {
    "name" : "rasidul hoque",
    "subject" : {
        "phy" : 98,
        "chem" : 89,
        "math" : 86
    }

}

print(student["name"])
print(student.get("name"))
# Out:
# rasidul hoque
# rasidul hoque

# %%
dic = {
    "name" : "rasidul",
    "age" : 23,
    "university" : "LU"
}

dic
# Out:
# {'name': 'rasidul', 'age': 23, 'university': 'LU'}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'age', 'university'])

# %%
type(dic)
# Out:
# dict

# %%
dic.values()
# Out:
# dict_values(['rasidul', 23, 'LU'])

# %%
dic2 = dic.copy()
dic2
# Out:
# {'name': 'rasidul', 'age': 23, 'university': 'LU'}

# %%
dic["age"] = 24
dic
# Out:
# {'name': 'rasidul', 'age': 24, 'university': 'LU'}

# %%
dic['dept'] = 'cse'
dic
# Out:
# {'name': 'rasidul', 'age': 24, 'university': 'LU', 'dept': 'cse'}

# %%
dic.update({'dept' : 'airthmetic'})
dic
# Out:
# {'name': 'rasidul', 'age': 24, 'university': 'LU', 'dept': 'airthmetic'}

# %%
dic.popitem()
dic
# Out:
# {'name': 'rasidul', 'age': 24, 'university': 'LU'}

# %%
dic.popitem()
dic
# Out:
# {'name': 'rasidul', 'age': 24}

# %%
dic.pop('age')
dic
# Out:
# {'name': 'rasidul'}

# %%
dic = {
    "name" : "rasidul",
    "age" : 23,
    "university" : "LU"
}

dic
# Out:
# {'name': 'rasidul', 'age': 23, 'university': 'LU'}

# %%
for x in dic:
    print(dic[x])
# Out:
# rasidul
# 23
# LU

# %%
# d2 = list(dic.items())
# d2

d2 = list(dic.values())
d2
# Out:
# ['rasidul', 23, 'LU']

# %%
n = int(input("Enter number of items: "))

d = {}
for i in range(n):
    key = input("Enter key: ")
    value = input("Enter value: ")
    d[key] = value

print(d)
# Out:
# {'name ': 'rash', 'dept': 'cse', 'dream': 'gura guri'}
