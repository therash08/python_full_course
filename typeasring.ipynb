# %%
name = 'rashidul'
age = 24
gpa = 3.00
is_student = True

# %%
name
age
# Out:
# 24

# %%
print(type(name))
print(type(age))
print(type(gpa))
print(type(name))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
gpa = int(gpa)
gpa
# Out:
# 3

# %%
age = str(age)
age
# Out:
# '24'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
name = ''
name = bool(name)
name
# Out:
# False
