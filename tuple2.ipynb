# %%
tup = ()
type(tup)
# Out:
# tuple

# %%
tup = ('ds', 'roni mia', 'lu', 1,3,5,7,True )
tup
# Out:
# ('ds', 'roni mia', 'lu', 1, 3, 5, 7, True)

# %%
tup[2]
# Out:
# 'lu'

# %%
tup[1]
# Out:
# 'roni mia'

# %%
tup[-1]
# Out:
# True

# %%
tup[2:5]
# Out:
# ('lu', 1, 3)

# %%
tup = ("rash",)
type(tup)
# Out:
# tuple

# %%
tup2 = 10,20,30,'rash'
tup2
# Out:
# (10, 20, 30, 'rash')

# %%
type(tup2)
# Out:
# tuple

# %%
tup2 = 'rash'
type(tup2)
# Out:
# str

# %%
tup2 = 'rash',
type(tup2)
# Out:
# tuple

# %%
tup
# Out:
# ('rash',)

# %%
tup2
# Out:
# ('rash',)

# %%
tup2 = 10,20,30,'rash'
tup2
# Out:
# (10, 20, 30, 'rash')

# %%
tup
# Out:
# ('rash',)

# %%
tup+tup2
# Out:
# ('rash', 10, 20, 30, 'rash')

# %%
tup2*4
# Out:
# (10,
#  20,
#  30,
#  'rash',
#  10,
#  20,
#  30,
#  'rash',
#  10,
#  20,
#  30,
#  'rash',
#  10,
#  20,
#  30,
#  'rash')

# %%
tup2.count(10)
# Out:
# 1

# %%
tup2.index(10)
# Out:
# 0

# %%
'rashh' in tup2
# Out:
# False

# %%
tuple = 'rasidul', 'hoque', 'chowdhury'
tuple
# Out:
# ('rasidul', 'hoque', 'chowdhury')

# %%
for i in tuple:
    print(i)
# Out:
# rasidul
# hoque
# chowdhury
