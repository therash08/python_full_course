# %%
import array as ar

# %%
ar1 = ar.array('i',[1, 2, 3, 4, 5])

# %%
ar1
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
ar1[0]
# Out:
# 1

# %%
ar1[0] = 10
ar1
# Out:
# array('i', [10, 2, 3, 4, 5])

# %%
ar1[2:4]
# Out:
# array('i', [3, 4])

# %%
ar1.append(6)
ar1
# Out:
# array('i', [10, 2, 3, 4, 5, 6])

# %%
del ar1[3]
ar1
# Out:
# array('i', [10, 2, 3, 5])

# %%
len(ar1)
# Out:
# 4

# %%
ar1.reverse()
ar1
# Out:
# array('i', [5, 3, 2, 10])

# %%
ar1.sort()
ar1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ar1.sort()
#       2 ar1
#
# AttributeError: 'array.array' object has no attribute 'sort'

# %%
import array

ar1 = array.array('i', [5, 2, 9, 1, 7])
temp = list(ar1)
temp.sort()
ar1 = array.array('i', temp)
print(ar1)
# Out:
# array('i', [1, 2, 5, 7, 9])

# %%
ar1.count(2)
# Out:
# 1

# %%
ar1.clear()
ar1
# Out:
# array('i')

# %%
ar1.pop(2)
ar1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ar1.pop(2)
#       2 ar1
#
# IndexError: pop from empty array

# %%
r = ar.array('i',[])
items = int(input())

for i in range(items):
    val = int(input("Enter value: "))
    r.append(val)
    print("Array elements: ", r)
# Out:
# Array elements:  array('i', [100])
# Array elements:  array('i', [100, 200])
# Array elements:  array('i', [100, 200, 20000])

# %%
r = ar.array('i',[])
items = int(input())

for i in range(items):
    val = int(input("Enter value: "))
    r.append(val)
print("Array elements: ", r)
# Out:
# Array elements:  array('i', [1, 2, 3, 4])
