# %%
if 5 < 0:
    print("code A")
    print("code A")
    print("code A")
    print("code A")
    print("code A")

# %%
condition = 5 > 0:

# %%
temp = 30


if temp > 15:
    print("this is rasidul")

elif temp > 25:

    print('rasidul hoque')

elif temp > 0:
    print("its a cool boy")
else:
    print("lalalala")
# Out:
# this is rasidul

# %%
x = 20
y = 10

if x>0 and x<100:
    print('x is good')
    
if y>0 and y<100:
    print('y is good')
# Out:
# x is good
# y is good

# %%
is_enable = True

if not is_enable:
    print('all bad')

# %%
panal_w = 900
panal_h = 2500


if panal_w <=1500:
    print("width is good")
    
else:
    print('width is not good')
# Out:
# width is good
