# %%
x = 10
y = 100
z = 10+y

z
# Out:
# 110

# %%
x,y,z
# Out:
# (10, 10, 30)

# %%
print(x+y+z)
# Out:
# 220

# %%
a = 'rasidul '
b = 'hoque'

c = a + b
c
# Out:
# 'rasidul hoque'

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
name = 'rasidul'

print('my name is: ' + name)
# Out:
# my name is: rasidul

# %%
print('my name is: {}'.format('erik'))
# Out:
# my name is: erik

# %%
print('hello')
print('-'*50)
print('hello\n'*50)
# Out:
# hello
# --------------------------------------------------
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
massage = 'im a boy whose name is rasidul hoque '
print('rashidul'not in massage)
# Out:
# True

# %%
a = 'concrete-10cm'
b = 'concrete-20cm'

print(a==b)
print(a!=b)
# Out:
# False
# True

# %%
a = 20
b = 3

print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a ** b =", a ** b)
print("a % b =", a % b)
# Out:
# a + b = 23
# a - b = 17
# a * b = 60
# a / b = 6.666666666666667
# a // b = 6
# a ** b = 8000
# a % b = 2

# %%
num = 10
is_even = num%2 == 0
is_odd = num %2 !=0

print(is_even)
print(is_odd)
# Out:
# True
# False

# %%
print(' a > b =', a > b)
print(' a < b =', a < b)
print(' a >= b =', a >= b)
print(' a <= b =', a <= b)
print(' a == b =', a == b)
print(' a != b =', a != b)
# Out:
#  a > b = True
#  a < b = False
#  a >= b = True
#  a <= b = False
#  a == b = False
#  a != b = True

# %%
mats1 = ['rasidl', 'sami', 'tanmoy']
mats2 = ['fahmid', 'rudro']

mats3 = mats1 + mats2
print(mats3)
# Out:
# ['rasidl', 'sami', 'tanmoy', 'fahmid', 'rudro']

# %%
print(mats1*10)
# Out:
# ['rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy', 'rasidl', 'sami', 'tanmoy']

# %%
print(mats1 == mats2)
# Out:
# False

# %%
# friends = 0

# friends = friends + 1


friends
# Out:
# 1

# %%
friends = friends * 3
friends
# Out:
# 243

# %%
friends = friends / 2
friends
# Out:
# 121.5

# %%
friends = friends / 3
friends
# Out:
# 40.5

# %%
remainder = friends % 2
friends
# Out:
# 40.5

# %%
x = 3.14
y = 4
z = 5
 
# result = round(x)
# result = abs(y)
# result = pow(4,3)
result = max(x,y,z)


result
# Out:
# 5

# %%
import math
x = 9.1
# print(math.pi)
# print(math.e)
# result = math.sqrt(x)
result = math.ceil(x)
result = math.floor(x)

result
# Out:
# 9

# %%
import math 

radius = input("enter the radius of a circle: ")

result2 = 2 * math.pi * radius
print(f"the result2 is: {result}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 import math
#       3 radius = input("enter the radius of a circle: ")
# ----> 5 result2 = 2 * math.pi * radius
#       6 print(f"the result2 is: {result}")
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
a = float(input("enter side A: "))
b = float(input("enter side B: "))

c = math.sqrt(pow(a,2) + pow(b,2))
print(c)
# Out:
# 22.360679774997898

# %% [markdown]
# logical_operators

# %%
temp = 78
is_raining = False

if temp > 35 or temp < 0  or is_raining:
    print("The outdoor event is cancelled")

else:
    print("The outdoor event is not cancelled")
# Out:
# The outdoor event is cancelled

# %%
temp = 50
is_sunny = True

if temp >= 28 and is_sunny:
    print("it is HOT outside ")
    print("it is sunny")
# Out:
# it is HOT outside
# it is sunny
