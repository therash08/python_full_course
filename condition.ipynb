# %%
num = 8
print("positive" if num > 0 else "negative" )
# Out:
# positive

# %%
num = 9


result = "EVEN" if num % 2 == 0 else "ODD"
print(result)
# Out:
# ODD

# %%
num = int(input('enter a number'))

if num % 2 == 0:
    print('even')
else:
    print("ODD")
# Out:
# ODD

# %%
num = 8
a = 5
b = 7

# %%
age = 23

if
