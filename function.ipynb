# %%
country = 'ban' 
def display():
    name = "rash"
    print(name)
    print(country)

display()
# Out:
# rash
# ban

# %%
a = 5
b = 10
sum = a+b
print(sum)
# Out:
# 15

# %%
def calc_sum(a,b):
    sum = a+b
    print(sum)
 

calc_sum(2,10)
calc_sum(30,40)
calc_sum(5,19)
# Out:
# 12
# 70
# 24

# %%
def calc_sum(a,b):
    return a+b

sum = calc_sum(157,398)
print(sum)
# Out:
# 555

# %%
def print_rash():
    print("rash")
    
print_rash()
# Out:
# rash

# %%
def calc_sum(a,b,c):
    sum = a+b+c
    avg = sum / 3
    print(avg)
    
    #return avg
    
calc_sum(1,4,8)
# Out:
# 4.333333333333333

# %%
print("therash", "chowdhury")
# Out:
# therash chowdhury

# %% [markdown]
# **FUNCTION IN PYTHON**
#
# Built_in_Function:
#
# print()
# len()
# type()
# range()

# %%
cities = ["dhaka", "sylhet", "ctg", "barishal", "sreemangal"]
we = ["rash", "sami", "fahmida", "musrat"]

# print(cities[0], end=" ")
# print(cities[1], end=" \n")

def print_len(list):
    print(len(list))
    
    
# print_len(cities)
# print_len(we)

def print_len(list):
    for item in list:
        print(item, end= " ")
        
print_list(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 18
#      15     for item in list:
#      16         print(item, end= " ")
# ---> 18 print_list(cities)
#
# NameError: name 'print_list' is not defined

# %%
n = 6
fact = 1
for i in range(1,n+1):
    fact *= i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720

# %%
def cal_fact(n):
    fact = 1
    for i in range(1, n+1):
        fact *= i
    print(fact)

cal_fact(3)
# Out:
# 6

# %%
def convert (used_val):
