# %%
def remove_duplicate(input_list):
    unique_list = []
    
    for item in input_list:
        if item not in unique_list:
          unique_li

# %%
input_list = [1,2,3,4,5,4,2,3,8]
remove_duplicate(input_list)


print(f'real list {input_list}')
print(f'unique list {remove_duplicate(input_list)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 input_list = [1,2,3,4,5,4,2,3,8]
# ----> 2 remove_duplicate(input_list)
#       5 print(f'real list {input_list}')
#       6 print(f'unique list {remove_duplicate(input_list)}')
#
# Cell In[12], line 6, in remove_duplicate(input_list)
#       4 for item in input_list:
#       5     if item not in unique_list:
# ----> 6       unique_li
#
# NameError: name 'unique_li' is not defined
