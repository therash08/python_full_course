# %%
price1 = 3.12124
price2 = -98.42
price3 = 12.654

print(f"price 1 is ${price1:.2f}")
print(f"price 2 is ${price2:.2f}")
print(f"price 3 is ${price3:.2f}")
# Out:
# price 1 is $3.12
# price 2 is $-98.42
# price 3 is $12.65
