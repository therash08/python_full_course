# %%
lambda arguments: expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def sum(x,y):
    return x+y
sum(7,9)
# Out:
# 16

# %%
f = lambda x,y: x*y
f(7,9)
f(3,8)
# Out:
# 24

# %%
def opp_high(x,y, opp):
    return opp(x,y)

opp_high(4,6, lambda x,y: x+y)
# Out:
# 10

# %%
num = [1,2,34,50,47,30]
num
# Out:
# [1, 2, 34, 50, 47, 30]

# %%
def sq(x):
    return x**x
sq(4)
# Out:
# 256

# %% [markdown]
# map
#
# (function, iteable object)

# %%
num = map(lambda x:x**2, num)
num

# %%
num = list(map(lambda x:x**2, num))
num
# Out:
# [1, 16, 1336336, 6250000, 4879681, 810000]

# %% [markdown]
# #filter(function, iteble object)

# %%
num = list(filter(lambda num: num%2 == 1, num))
num
# Out:
# [1, 4879681]

# %%
from functools import reduce 
reduce (lambda a,b:a+b , num )
# Out:
# 4879682
