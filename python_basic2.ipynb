# %%
print("THE RASH")
# Out:
# THE RASH

# %%
print('hello rash!welcome')
# Out:
# hello rash!welcome

# %%
var = "hello rash"
print(var)
print('my sentence is ' + var)
# Out:
# hello rash
# my sentence is hello rash

# %%
id(var)
# Out:
# 1853110315696

# %%
import sys 
sys.getsizeof(var)
# Out:
# 51

# %%
x = 100
x
# Out:
# 100

# %%
y = 100
y
# Out:
# 100

# %%
id(x)
# Out:
# 140710516326408

# %%
id(y)
# Out:
# 140710516326408

# %%
name = 'rash'
name
# Out:
# 'rash'

# %%
data = input()
print(data)

# %%
type(data)
# Out:
# str

# %%
x = input()
y = input()

x+y
# Out:
# '7'

# %%
type(y)
# Out:
# str

# %%
x = int(x)
y = int(y)

x+y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 x = int(x)
# ----> 2 y = int(y)
#       4 x+y
#
# ValueError: invalid literal for int() with base 10: ''

# %%
x = int(input("enter 1st number: "))
print(x)
# Out:
# 100

# %%
x = int(input())
y = int(input())

x + y
# Out:
# 135

# %%
x = int(input("enter your number: "))
y = float(input("enter a number: "))

# %%
x
# Out:
# 9

# %%
y
# Out:
# 0.9

# %%
data = "rasidul hoque chowdhury"
type(data)
# Out:
# str

# %%
len(data)
# Out:
# 23

# %%
import sys
sys.getsizeof(data)
# Out:
# 64

# %%
data.count("rasidul")
# Out:
# 1

# %%
sub = "rasidul hoque"
data.count(sub)
# Out:
# 1

# %% [markdown]
# python string method

# %%
name = "rasidul hoque chowdhury"
name.find("hoque")
# Out:
# 8

# %%
data.find('l',6,10)
# Out:
# 6

# %%
data.find("khj")
# Out:
# -1

# %%
data.index("khfroi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data.index("khfroi")
#
# ValueError: substring not found

# %%
data.lower()
# Out:
# 'rasidul hoque chowdhury'

# %%
name.upper()
# Out:
# 'RASIDUL HOQUE CHOWDHURY'

# %%
x.split(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x.split(name)
#
# NameError: name 'x' is not defined

# %% [markdown]
# all about data types

# %%
x = 10
y = 15.78
z = 10+7j

type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
is
# Out:
#   Cell In[6], line 1
#     is
#     ^
# SyntaxError: invalid syntax

# %%
isinstance(z,complex)
# Out:
# True

# %%
isinstance(x,float)
# Out:
# False

# %%
x = True

# %%
x
# Out:
# True

# %% [markdown]
# **sequence Data**

# %%
l = [1,2,3,4,True,[1,2], 'rash',(0,9,8,7,6)]
l
# Out:
# [1, 2, 3, 4, True, [1, 2], 'rash', (0, 9, 8, 7, 6)]

# %%
l(-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 l(-1)
#
# TypeError: 'list' object is not callable

# %%
l[0]
# Out:
# 1

# %%
l[-1]
# Out:
# (0, 9, 8, 7, 6)

# %%
type(l)
# Out:
# list

# %%
t  = (1,2,3,4,'rash')
t
# Out:
# (1, 2, 3, 4, 'rash')

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 1

# %%
t[0:4]
# Out:
# (1, 2, 3, 4)
