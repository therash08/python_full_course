# %%
def fact(x):
    if x == 0:
        return 1
    return x* fact(x-1)

# %%
fact(5)
# Out:
# 120

# %%
fact(8)
# Out:
# 40320

# %%
def web():
    print('rasidul')
    web()
web()
# Out:
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# rasidul
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000
