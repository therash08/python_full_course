# %%
collection = {1,2,3,4,5, 2,4, "rash"}

print(collection)
print(len(collection))
# Out:
# {1, 2, 3, 4, 5, 'rash'}
# 6

# %%
collection = {}
print(type(collection))
# Out:
# <class 'dict'>

# %%
set1 = {1,2,3,4}
set2 = {4,5,6,7,8,0}

print(set1.union(set2))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# Jupyter: Clear Kernel Cache
