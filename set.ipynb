# %%
collection = {1,2,3,4,5, 2,4, "rash"}

print(collection)
print(len(collection))
# Out:
# {1, 2, 3, 4, 5, 'rash'}
# 6

# %%
collection = {}
print(type(collection))
# Out:
# <class 'dict'>

# %%
set1 = {1,2,3,4}
set2 = {4,5,6,7,8,0}

print(set1.union(set2))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
set1 = {1,2,3,4,5,6, 'ao', (10,20)}
set1
# Out:
# {(10, 20), 1, 2, 3, 4, 5, 6, 'ao'}

# %%
type(set1)
# Out:
# set

# %%
set2 = {}
li = []

type(li)
type(set2)
# Out:
# dict

# %%
set3 = set()
type(set3)
# Out:
# set

# %%
li
# Out:
# []

# %%
set2
# Out:
# {}

# %%
set1.add(100)
set1
# Out:
# {(10, 20), 1, 100, 2, 3, 4, 5, 6, 'ao'}

# %%
set

# %% [markdown]
# Frozen Set

# %%
s1 = {1,2,3,4,5}
set2 = {'a', 'b'}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2
# Out:
# {'a', 'b'}

# %%
type(s1)
# Out:
# set

# %%
s1.add(10)
s1
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
s3 = frozenset(s1)
s3
# Out:
# frozenset({1, 2, 3, 4, 5, 10})

# %%
type(s3)
# Out:
# frozenset

# %%
s3.add(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s3.add(100)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s3.remove(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s3.remove(4)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
l1 =[1,2,3,4,5]
s4 = frozenset(l1)
s4
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
 s1.union(s2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s1.union(s2)
#
# NameError: name 's2' is not defined

# %%
s5 = {1,2,3,4,5}
s6 = {4,5,6,7,8}
s5.intersection(s6)
# Out:
# {4, 5}

# %%
s5.difference(s6)
# Out:
# {1, 2, 3}

# %%
s = frozenset(s5)
s
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
from IPython.display import Image

# %%
s5.add(100)
s5
# Out:
# {1, 2, 3, 4, 5, 100}
